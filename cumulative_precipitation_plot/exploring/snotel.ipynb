# %%
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt

# %%
snotel_data = xr.open_zarr('/data0/nksp2/skagit/skagit_2/skagit-met/experiments_2/data/snotel/2000-01-01_2025-12-31_SNOTEL_daily_data.zarr')
snotel_data = xr.open_zarr('/data0/nksp2/skagit/skagit_2/skagit-met/data/2003-10-18_2003-10-31_SNOTEL_daily_data.zarr')
snotel_data
# Out:
# <xarray.Dataset> Size: 864B
# Dimensions:        (time: 14, site: 4)
# Coordinates:
#   * time           (time) datetime64[ns] 112B 2003-10-18 ... 2003-10-31
#   * site           (site) <U11 176B '711:WA:SNTL' ... '990:WA:SNTL'
#     elevation_ft   (site) float64 32B dask.array<chunksize=(4,), meta=np.ndarray>
#     lat            (site) float64 32B dask.array<chunksize=(4,), meta=np.ndarray>
#     lon            (site) float64 32B dask.array<chunksize=(4,), meta=np.ndarray>
#     site_name      (site) object 32B dask.array<chunksize=(4,), meta=np.ndarray>
# Data variables:
#     PRECIPITATION  (time, site) float64 448B dask.array<chunksize=(14, 4), meta=np.ndarray>

# %%
print(snotel_data.site_name.values)
# Out:
# ['Rainy Pass' 'Thunder Basin' 'Swamp Creek' 'Beaver Pass']

# %%
plt.plot(snotel_data.time.values, snotel_data['PRECIPITATION'].sel(site='SKAGIT RIVER AT MOUNT VERNON').values)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/datasets_analysis/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
