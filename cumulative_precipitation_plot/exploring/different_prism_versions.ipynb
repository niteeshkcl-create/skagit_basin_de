# %%
from pathlib import Path
import os

# %%
# ----------- Paths ---------------------
data_transfer_version_dir = Path("/data0/skagit_met/data_transfer/data/PRISM/2001-2010/ppt_20030101_4km.zip")
newer_version_dir = Path("/data0/hernanqd/plots_code/skagit_basin_de/cumulative_precipitation_plot/exploring/prism_ppt_us_25m_20030101.zip")

# %%
VAULT_DIR = "/data0/skagit_met/data_transfer/data"
BASE_DIR = "/data0/hernanqd/plots_code/skagit_basin_de"
HUC8_GEO = os.path.join(BASE_DIR, "data/GIS/SkagitSubBasin_HUC8.geojson")
